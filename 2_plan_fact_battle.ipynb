# %%
import pandas as pd
import numpy as np

# %%
df_plan = pd.read_csv('тест_бюджет.csv').replace(';', ',')


df_fact = pd.read_csv('data.csv')

# %%
df_plan
# Out:
#                                                                       object;object_type; planned_expense ;planned_revenue
# СКВ.1496Л-56 Поточное [дог.17С1490] [ЗБП];Забой... 00 ₽ ;13 000 000                                                 0.0
# СКВ.1891Л-299 Тевлинско-Русскинское [дог.17С149... 00 ₽ ;2 470 000                                                  0.0
# СКВ.2057Н-44Б Повховское [дог.17С1490] [ЗБП];За... 00 ₽ ;4 290 000                                                  0.0
# СКВ.227-23 Повховское [дог.17С1490] [ЗБП];Забой... 00 ₽ ;5 200 000                                                  0.0
# СКВ.10442Р Шушминское [дог.19С1114] [ББ];Бурени... 00 ₽ ;29 900 000                                                 0.0
# СКВ.12301Г-123 им. А.Усольцева (бывш Имилорское... 00 ₽ ;45 500 000                                                 0.0
# СКВ.12304Г-123 им. А.Усольцева (бывш Имилорское... 00 ₽ ;35 100 000                                                 0.0
# ...

# %%
df_fact
# Out:
#   contractor contract_num        date  \
# 0     Лукойл      17С1490  07.08.2017
# 1     Лукойл      17С1490  07.08.2018
# 2     Лукойл      17С1490  07.08.2019
# 3     Лукойл      17С1490  07.08.2020
# 4     Лукойл      17С1490  07.08.2023
# 5     Лукойл      17С1490  07.08.2024
# 6     Лукойл      17С1490  07.08.2025
# 7     Лукойл      17С1490  07.08.2026
# 8     Лукойл      17С1490  07.08.2029
#
#                                          object_name     expenses  \
# 0          СКВ.1496Л-56 Поточное [дог.17С1490] [ЗБП]         0.00
# 1  СКВ.1891Л-299 Тевлинско-Русскинское [дог.17С14...   1835273.99
# 2       СКВ.2057Н-44Б Повховское [дог.17С1490] [ЗБП]   2249093.08
# 3          СКВ.227-23 Повховское [дог.17С1490] [ЗБП]   2694737.75
# 4           СКВ.10442Р Шушминское [дог.19С1114] [ББ]  36700045.94
# 5  СКВ.12301Г-123 им. А.Усольцева (бывш Имилорско...      8800.00
# 6  СКВ.12304Г-123 им. А.Усольцева (бывш Имилорско...     28352.48
# ...
